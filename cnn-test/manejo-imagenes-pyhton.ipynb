# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io

# %%
im = io.imread('archive/Mara.jpeg')

# %%
im.shape
# Out:
# (800, 600, 3)

# %%
plt.imshow(im)

# %%
r = im[:,:,0]
g = im[:,:,1]
b = im[:,:,2]

# %%
plt.imshow(b.T)

# %%
r.shape
aux_dim = np.zeros([800,600])

# %%
red = np.dstack((r, aux_dim, aux_dim)).astype(np.uint8)
plt.imshow(red)

# %%
plt.imshow(im[150:765, 560:780])

# %%
import tensorflow as tf
# Out:
# 2023-08-23 03:35:23.978713: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-23 03:35:24.008237: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-23 03:35:24.008860: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-23 03:35:24.649953: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
